# %%
spark.sql("use catalog dbricks")
spark.sql("use schema bookstore_etl_prod")

# %%
spark.sql("select count(*) from dbricks.bookstore_etl_prod.bronze").display()

# %%
# %sql
SELECT * FROM dbricks.bookstore_etl_prod.event_log;

# %%
# %sql
SELECT details:flow_progress:data_quality:expectations, *
FROM dbricks.bookstore_etl_prod.event_log
WHERE details:flow_progress:data_quality:expectations IS NOT NULL;
